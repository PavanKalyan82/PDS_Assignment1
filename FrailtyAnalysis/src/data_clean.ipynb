# %%
import pandas as pd

# %%
df = pd.read_csv('/content/raw_data/raw_data.csv')
df.head()
# Out:
#    Height(Inches)  Weight(Pounds)  Age  GripStrength Frailty
# 0            65.8             112   30            30       N
# 1            71.5             136   19            31       N
# 2            69.4             153   45            29       N
# 3            68.2             142   22            28       Y
# 4            67.8             144   29            24       Y

# %%
df.isnull().sum()
# Out:
# Height(Inches)    0
# Weight(Pounds)    0
# Age               0
# GripStrength      0
# Frailty           0
# dtype: int64

# %%
df.to_csv('/content/clean_data/clean_data.csv')
